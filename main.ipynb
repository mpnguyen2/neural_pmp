# %%
from train import train_env
train_env('mountain_car', num_examples=3200, mode=0, num_examples_phase2=0.05, 
              retrain_phase1=True, retrain_phase2=True, num_additional_train=2)
# Out:
# Training environment mountain_car:
#
#
# Training phase 1...
#
# Epoch 1:
# Average loss for 1th iteration is: 10.163604740987857
# Average loss for 21th iteration is: 7.3571517135586975
# Average loss for 41th iteration is: 6.059726393134181
# Average loss for 61th iteration is: 5.296778874402738
# Average loss for 81th iteration is: 4.880164139444747
#
# Epoch 2:
# Average loss for 1th iteration is: 4.4596410535505875
# Average loss for 21th iteration is: 3.527368086788145
# Average loss for 41th iteration is: 3.518939737195139
# Average loss for 61th iteration is: 3.4159405883467784
# Average loss for 81th iteration is: 3.3895337313071945
#
# Epoch 3:
# Average loss for 1th iteration is: 4.1351521450251445
# Average loss for 21th iteration is: 3.2665070048263605
# Average loss for 41th iteration is: 3.330929971933556
# Average loss for 61th iteration is: 3.36199633157222
# Average loss for 81th iteration is: 3.3884997476043366
#
# Epoch 4:
# ...

# %%
from test import test
import numpy as np
test('mountain_car', time_steps=list(np.arange(0, 100, 0.2)), log_interval=1, test_trained=True)
# Out:
# Test mountain_car:
# Done finding trajectory...
# terminal cost: 1.6197139024734497
# terminal cost: 1.623817801475525
# terminal cost: 1.6279159784317017
# terminal cost: 1.6319948434829712
# terminal cost: 1.6360585689544678
# terminal cost: 1.6401054859161377
# terminal cost: 1.644134759902954
# terminal cost: 1.6481482982635498
# terminal cost: 1.6521415710449219
# terminal cost: 1.6561145782470703
# terminal cost: 1.6600679159164429
# terminal cost: 1.6639995574951172
# terminal cost: 1.6679046154022217
# terminal cost: 1.6717898845672607
# terminal cost: 1.675650954246521
# terminal cost: 1.6794875860214233
# terminal cost: 1.6832984685897827
# terminal cost: 1.6870838403701782
# terminal cost: 1.6908422708511353
# terminal cost: 1.6945735216140747
# terminal cost: 1.6982766389846802
# terminal cost: 1.7019511461257935
# terminal cost: 1.7055962085723877
# terminal cost: 1.7092114686965942
# terminal cost: 1.7127968072891235
# terminal cost: 1.7163528203964233
# ...
