# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
from test import benchmarks

benchmarks(env_name='bee_colony', num_trajs=10, time_steps=list(np.arange(0, 1.0, 0.1)))

# %%
import numpy as np
from test import benchmarks

benchmarks(env_name='prodconsume', num_trajs=10,
           time_steps=list(np.arange(0, 1.0, 0.01)),
           eval_along_traj=True)
